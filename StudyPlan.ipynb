# %% [markdown]
# # 🌳 Python Algorithms & Data Structures Learning Tree
#
# A progressive map of my journey learning Python DSA (Coursera – University of Colorado).
# 🟢 = Completed | 🟡 = In Progress | ⚪️ = Not Started
#
# ---
#
# ## 1. 📌 Introduction to Algorithms and Complexity
#
# - [🟢] What is an Algorithm?
# - [🟢] Time & Space Complexity (Big-O)
# - [🟢] Use cases of algorithms in real life
# - [🟢] Quiz / Practical Application
#
# ---
#
# ## 2. 📊 Sorting Algorithms
#
# - [🟡] Insertion Sort
#   - [🟢] Pseudocode
#   - [🟡] Python implementation
#   - [⚪️] Time/space analysis
# - [⚪️] Selection Sort
# - [⚪️] Bubble Sort
# - [⚪️] Merge Sort
# - [⚪️] Quick Sort
# - [⚪️] Compare sorting algorithms

# %% [markdown]
# # 🧮 Mathematics
#
# A progressive map of my journey learning Python DSA (Coursera – University of Colorado).
# 🟢 = Completed | 🟡 = In Progress | ⚪️ = Not Started
#
# ---
# ## 1. ∑ Calculus
#
#
# ---
#
# ## 2. 📏 Linear Algebra
#
#
# ### 2.1. 🧠 Foundations
#     - [🟢] Scalars, Vectors, and Matrices
#     - [🟡] Matrix Operations (Addition, Multiplication, Transpose)
#     - [⚪️] Identity and Inverse Matrices
#     - [⚪️] Dot Product and Cross Product
#     - [⚪️] Matrix Notation and Dimensions
#
#
# ### 2.2. 📏 Linear Systems
#
#     - [⚪️] Solving Systems of Linear Equations
#     - [⚪️] Gaussian Elimination
#     - [⚪️] Row Echelon Form & Reduced Row Echelon Form
#     - [⚪️] Rank and Consistency
#
# ### 2.3. 📐 Vector Spaces
#
# - [⚪️] Vector Subspaces
# - [⚪️] Linear Independence
# - [⚪️] Span and Basis
# - [⚪️] Dimension
#
#
# ### 2.4. 🔄 Transformations
#
# - [⚪️] Linear Transformations
# - [⚪️] Matrix Representation of Transformations
# - [⚪️] Kernel and Image
# - [⚪️] Change of Basis
#
#
# ### 2.5. 🔢 Determinants & Inverses
#
# - [⚪️] Determinant Properties
# - [⚪️] Determinant Computation (2x2, 3x3, n×n)
# - [⚪️] Cramer’s Rule
# - [⚪️] Inverse via Adjugate and Row Reduction
#
#
# ### 2.6. 🧬 Eigenvalues and Eigenvectors
#
# - [⚪️] Characteristic Polynomial
# - [⚪️] Finding Eigenvalues
# - [⚪️] Finding Eigenvectors
# - [⚪️] Diagonalization

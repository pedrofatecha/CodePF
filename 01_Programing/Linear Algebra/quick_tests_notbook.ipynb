# %%
# %pip install collections
# Out:
# ERROR: Could not find a version that satisfies the requirement collections (from versions: none)
# ERROR: No matching distribution found for collections
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import json

output_dir = Path('output')
output_dir.mkdir(exist_ok=True)

content = '''```mermaid
flowchart TD
  A[AI in Audit at EY]
  A --> B[Role & Context]
  B --> B1[Data Strategist & ERP]
  B --> B2[Digital data roads]
  A --> C[Daily AI Usage]
  C --> C1[Copilot / VS Code Copilot]
  C --> C2[Summaries & drafting]
  C --> C3[Human in the loop]
  A --> D[AI Use Cases]
  D --> D1[Workpaper documentation]
  D --> D2[Methodology wording]
  D --> D3[Procedures & coverage]
  A --> E[Benefits]
  E --> E1[Speed & productivity]
  E --> E2[Consistency]
  E --> E3[Data-driven audits]
  A --> F[Risks & Challenges]
  F --> F1[Client-data limits]
  F --> F2[Hallucinations]
  F --> F3[Black-box concerns]
  A --> G[EY Approach]
  G --> G1[Human in the loop]
  G --> G2[Governance & caution]
  G --> G3[EY Canvas & agents]
  A --> H[Personal Development]
  H --> H1[Deeper expertise]
  H --> H2[More skepticism]
  H --> H3[Continuous upskilling]
```
'''

path = r'/Users/pedrofatecha/GitHub/CodePF/Linear Algebra/ai_in_audit_mindmap_mermaid.md'
path.write_text(content, encoding='utf-8')

print(path.as_posix())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 41
#       7 content = '''```mermaid
#       8 flowchart TD
#       9   A[AI in Audit at EY]
#    (...)
#      37 ```
#      38 '''
#      40 path = r'/Users/pedrofatecha/GitHub/CodePF/Linear Algebra/ai_in_audit_mindmap_mermaid.md'
# ---> 41 path.write_text(content, encoding='utf-8')
#      43 print(path.as_posix())
#
# AttributeError: 'str' object has no attribute 'write_text'
